# %% [markdown]
# > 4/6/22, 12:18 AM image_classifier_using_CNN\_ - Jupyter Notebook
# >
# > In \[54\]:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4<br />
# 5<br />
# 6</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# <strong>import</strong> tensorflow <strong>as</strong> tf<br />
# <strong>from</strong> tensorflow.keras <strong>import</strong>
# datasets,layers,models<br />
# <strong>import</strong> matplotlib.pyplot <strong>as</strong> plt<br />
# <strong>import</strong> numpy <strong>as</strong> np<br />
# <strong>from</strong> sklearn.metrics <strong>import</strong>
# confusion_matrix,classification_report</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>In [55]:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#gautami kadam</em><br />
# (X_train,y_train),(X_test,y_test) <strong>=</strong>
# datasets.cifar10.load_data() X_train.shape</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>55]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > (50000, 32, 32, 3)
# >
# > In \[56\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# X_test.shape <em>#32x32 is size and 3 represents RGB</em></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>56]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > (10000, 32, 32, 3)
# >
# > In \[57\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# y_train.shape</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>57]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > (50000, 1)
# >
# > In \[86\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# y_train[:5] <em>#6 frog 9 truck</em></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>86]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > array(\[6, 9, 9, 4, 1\], dtype=uint8)
# >
# > In \[87\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# <em>#2D to 1D conversion</em><br />
# y_train <strong>=</strong> y_train.reshape(<strong>-</strong>1,)<br />
# y_train[:5]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>87]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > array(\[6, 9, 9, 4, 1\], dtype=uint8)
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>1/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>4/6/22, 12:18 AM</p>
# </blockquote></th>
# <th>image_classifier_using_CNN_ - Jupyter Notebook</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > In \[60\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# clas <strong>=</strong>
# ["airplane","automobile","bird","cat","deer","dog","frog",
# "horse","ship","truck"]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > In \[61\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4<br />
# 5<br />
# 6</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# <em>#fuction for plotting of images</em><br />
# <strong>def</strong>plot(X,y,index):<br />
# plt.figure(figsize<strong>=</strong>(15,2))<br />
# plt.imshow(X[index])<br />
# plt.xlabel(clas[y[index]])</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [</p>
# </blockquote></td>
# <td><blockquote>
# <p>62]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# plot(X_train,y_train,0) <em>#frog</em></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > <img
# > src="attachment:vertopal_9a3a53faed6f4b65b00453e804a2963d/media/image1.png"
# > style="width:1.48056in;height:1.625in" />
# >
# > In \[63\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# plot(X_train,y_train,1) <em>#truck</em></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > <img
# > src="attachment:vertopal_9a3a53faed6f4b65b00453e804a2963d/media/image2.png"
# > style="width:1.48056in;height:1.62639in" />
# >
# > In \[96\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4<br />
# 5<br />
# 6<br />
# 7</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# <em>#normalize the image in the form of 0 and 1</em><br />
# <em>#as we now that RGB has channel range from 0 to 255 #so to normalize
# the image we need to divide by 255</em></p>
# <p>X_train <strong>=</strong> X_train<strong>/</strong>255.0<br />
# X_test <strong>=</strong> X_test<strong>/</strong>255.0</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>2/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>4/6/22, 12:18 AM</p>
# </blockquote></th>
# <th>image_classifier_using_CNN_ - Jupyter Notebook</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > In \[98\]:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4<br />
# 5<br />
# 6<br />
# 7<br />
# 8<br />
# 9<br />
# 10<br />
# 11<br />
# 12</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# <em>#first lets try using ANN</em><br />
# ann <strong>=</strong> models.Sequential([<br />
# layers.Flatten(input_shape<strong>=</strong>(32,32,3)),
# layers.Dense(3000,activation<strong>=</strong>'relu'),
# layers.Dense(1000,activation<strong>=</strong>'relu'),
# layers.Dense(10,activation<strong>=</strong>'softmax') ])<br />
# ann.compile(optimizer<strong>=</strong>'SGD',loss<strong>=</strong>'sparse_categorical_crossentropy',
# metrics<strong>=</strong>['accuracy'])</p>
# <p>ann.fit(X_train,y_train,epochs<strong>=</strong>5)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>Epoch 1/5</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 1563/1563 \[==============================\] - 119s 76ms/step - loss:
# > 2.3011 - accuracy: 0.1232
# > Epoch 2/5
# > 1563/1563 \[==============================\] - 117s 75ms/step - loss:
# > 2.3000 - accuracy: 0.1274
# > Epoch 3/5
# > 1563/1563 \[==============================\] - 121s 77ms/step - loss:
# > 2.2993 - accuracy: 0.1428
# > Epoch 4/5
# > 1563/1563 \[==============================\] - 117s 75ms/step - loss:
# > 2.2984 - accuracy: 0.1384
# > Epoch 5/5
# > 1563/1563 \[==============================\] - 116s 75ms/step - loss:
# > 2.2974 - accuracy: 0.1445
# >
# > Out\[98\]:
# >
# > \<keras.callbacks.History at 0x7fc13df0bc50\>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>3/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>4/6/22, 12:18 AM</p>
# </blockquote></th>
# <th>image_classifier_using_CNN_ - Jupyter Notebook</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > In \[99\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# y_pred <strong>=</strong> ann.predict(X_test)<br />
# y_pred_clas <strong>=</strong> [np.argmax(element) <strong>for</strong>
# element <strong>in</strong> y_pred]<br />
# print("Classification Report:
# \n",classification_report(y_test,y_pred_clas))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Clas</p>
# </blockquote></td>
# <td>Classification Report:</td>
# </tr>
# </tbody>
# </table>
#
# > precision recall f1-score support
# >
# > 0 0.27 0.58 0.37 1000
# > 1 0.00 0.00 0.00 1000
# > 2 0.13 0.58 0.21 1000
# > 3 0.00 0.00 0.00 1000
# > 4 0.00 0.00 0.00 1000
# > 5 0.31 0.06 0.10 1000
# > 6 0.38 0.04 0.08 1000
# > 7 0.00 0.00 0.00 1000
# > 8 0.00 0.00 0.00 1000
# > 9 0.23 0.67 0.34 1000
# >
# > accuracy 0.19 10000 macro avg 0.13 0.19 0.11 10000 weighted avg 0.13
# > 0.19 0.11 10000
# >
# > /usr/local/lib/python3.7/dist-packages/sklearn/metrics/\_classification.py:13
# > 18: UndefinedMetricWarning: Precision and F-score are ill-defined and
# > being set to 0.0 in labels with no predicted samples. Use
# > \`zero_division\` paramete r to control this behavior.
# >
# > \_warn_prf(average, modifier, msg_start, len(result))
# > /usr/local/lib/python3.7/dist-packages/sklearn/metrics/\_classification.py:13
# > 18: UndefinedMetricWarning: Precision and F-score are ill-defined and
# > being set to 0.0 in labels with no predicted samples. Use
# > \`zero_division\` paramete r to control this behavior.
# >
# > \_warn_prf(average, modifier, msg_start, len(result))
# > /usr/local/lib/python3.7/dist-packages/sklearn/metrics/\_classification.py:13
# > 18: UndefinedMetricWarning: Precision and F-score are ill-defined and
# > being set to 0.0 in labels with no predicted samples. Use
# > \`zero_division\` paramete r to control this behavior.
# >
# > \_warn_prf(average, modifier, msg_start, len(result))
# >
# > In \[100\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4<br />
# 5<br />
# 6<br />
# 7<br />
# 8<br />
# 9<br />
# 10<br />
# 11<br />
# 12<br />
# 13</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# <em>#now lets try using Cnn</em><br />
# cnn <strong>=</strong> models.Sequential([<br />
# layers.Conv2D(filters<strong>=</strong>32,kernel_size<strong>=</strong>(3,3),activation<strong>=</strong>'relu',input_shape<strong>=</strong>(32,
# layers.MaxPooling2D((2,2)),</p>
# <p>layers.Conv2D(filters<strong>=</strong>64,kernel_size<strong>=</strong>(3,3),activation<strong>=</strong>'relu'),
# layers.MaxPooling2D((2,2)),</p>
# <p>layers.Flatten(),<br />
# layers.Dense(64,activation<strong>=</strong>'relu'),<br />
# layers.Dense(10,activation<strong>=</strong>'softmax')<br />
# ])</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>4/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>4/6/22, 12:18 AM</p>
# </blockquote></th>
# <th>image_classifier_using_CNN_ - Jupyter Notebook</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > In \[101\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3<br />
# 4</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# cnn.compile(optimizer<strong>=</strong>'adam',<br />
# loss<strong>=</strong>'sparse_categorical_crossentropy',
# metrics<strong>=</strong>['accuracy'])</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > In \[102\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# cnn.fit(X_train,y_train,epochs<strong>=</strong>10)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Epoc</p>
# </blockquote></td>
# <td><blockquote>
# <p>h 1/10</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > 1563/1563 \[==============================\] - 64s 41ms/step - loss:
# > 2.3028 - accuracy: 0.0992
# > Epoch 2/10
# > 1563/1563 \[==============================\] - 64s 41ms/step - loss:
# > 2.3028 - accuracy: 0.0994
# > Epoch 3/10
# > 1563/1563 \[==============================\] - 65s 41ms/step - loss:
# > 2.3027 - accuracy: 0.0994
# > Epoch 4/10
# > 1563/1563 \[==============================\] - 64s 41ms/step - loss:
# > 2.3028 - accuracy: 0.0984
# > Epoch 5/10
# > 1563/1563 \[==============================\] - 65s 41ms/step - loss:
# > 2.3028 - accuracy: 0.1005
# > Epoch 6/10
# > 1563/1563 \[==============================\] - 65s 41ms/step - loss:
# > 2.3028 - accuracy: 0.0989
# > Epoch 7/10
# > 1563/1563 \[==============================\] - 64s 41ms/step - loss:
# > 2.3028 - accuracy: 0.1004
# > Epoch 8/10
# > 1563/1563 \[==============================\] - 64s 41ms/step - loss:
# > 2.3028 - accuracy: 0.0996
# > Epoch 9/10
# > 1563/1563 \[==============================\] - 64s 41ms/step - loss:
# > 2.3028 - accuracy: 0.0973
# > Epoch 10/10
# > 1563/1563 \[==============================\] - 65s 42ms/step - loss:
# > 2.3028 - accuracy: 0.0976
# >
# > Out\[102\]:
# >
# > \<keras.callbacks.History at 0x7fc13def2710\>
# >
# > In \[103\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# cnn.evaluate(X_test,y_test)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>313/</p>
# </blockquote></td>
# <td>313/313 [==============================] - 4s 14ms/step - loss:
# 2.3026 - acc</td>
# </tr>
# </tbody>
# </table>
#
# > uracy: 0.1000
# >
# > Out\[103\]:
# >
# > \[2.302610158920288, 0.10000000149011612\]
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>5/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>4/6/22, 12:18 AM</p>
# </blockquote></th>
# <th>image_classifier_using_CNN_ - Jupyter Notebook</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > In \[104\]:
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# y_pred <strong>=</strong> cnn.predict(X_test)<br />
# y_pred[:5]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>Out[104]:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > array(\[\[0.09988279, 0.10026827, 0.10043065, 0.09972812, 0.10072629,
# > 0.10089421, 0.0999796 , 0.09824063, 0.10011476, 0.09973473\],
# > \[0.09988279, 0.10026827, 0.10043065, 0.09972812, 0.10072629,
# > 0.10089421, 0.0999796 , 0.09824063, 0.10011476, 0.09973473\],
# > \[0.09988279, 0.10026827, 0.10043065, 0.09972812, 0.10072629,
# > 0.10089421, 0.0999796 , 0.09824063, 0.10011476, 0.09973473\],
# > \[0.09988279, 0.10026827, 0.10043065, 0.09972812, 0.10072629,
# > 0.10089421, 0.0999796 , 0.09824063, 0.10011476, 0.09973473\],
# > \[0.09988279, 0.10026827, 0.10043065, 0.09972812, 0.10072629,
# > 0.10089421, 0.0999796 , 0.09824063, 0.10011476, 0.09973473\]\],
# > dtype=float32)
# >
# > In \[105\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2<br />
# 3</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# y_clas <strong>=</strong> [np.argmax(element) <strong>for</strong>
# element <strong>in</strong> y_pred ] y_clas[:5]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>105]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \[5, 5, 5, 5, 5\]
# >
# > In \[106\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1<br />
# 2</p>
# </blockquote></th>
# <th><blockquote>
# <p><em>#Gautami Kadam</em><br />
# y_test[:5]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>106]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > array(\[\[3\],
# > \[8\],
# > \[8\],
# > \[0\],
# > \[6\]\], dtype=uint8)
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>6/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>4/6/22, 12:18 AM</p>
# </blockquote></th>
# <th>image_classifier_using_CNN_ - Jupyter Notebook</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > In \[107\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>1</th>
# <th><blockquote>
# <p>plot(X_test,y_test,3)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>----</p>
# </blockquote></td>
# <td>---------------------------------------------------------------------------</td>
# </tr>
# </tbody>
# </table>
#
# > TypeError Traceback (most recent call last)
# > \<ipython-input-107-a0eeb72295ed\> in \<module\>()
# > ----\> 1plot(X_test,y_test,3)
# >
# > \<ipython-input-61-5b9cd1dde118\> in plot(X, y, index) **3**
# > plt.figure(figsize=(15,2))
# > **4** plt.imshow(X\[index\])
# > ----\> 5plt.xlabel(clas\[y\[index\]\])
# >
# > TypeError: only integer scalar arrays can be converted to a scalar
# > index
# >
# > <img
# > src="attachment:vertopal_9a3a53faed6f4b65b00453e804a2963d/media/image3.png"
# > style="width:1.48056in;height:1.47917in" />
# >
# > In \[108\]:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>1</th>
# <th><blockquote>
# <p>clas[y_clas[7]]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[</p>
# </blockquote></td>
# <td><blockquote>
# <p>108]:</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > 'dog'
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>localhost:8888/notebooks/Downloads/image_classifier_using_CNN_.ipynb</p>
# </blockquote></th>
# <th>7/7</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
